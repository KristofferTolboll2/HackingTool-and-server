# %%
from string import ascii_letters
import requests
import time
from multiprocessing import Pool


def generate_ASCII():
    for letter in ascii_letters:
        for letter2 in ascii_letters:
            yield letter + letter2

ASCII_list = generate_ASCII()


if __name__ == '__main__':
    start = time.time()
    for pair in ASCII_list:
        r = requests.post("http://127.0.0.1:5000/", json={"password": pair})
        if r.status_code == 200:
            print(f'You h8ck3d the s3rv3r m8 {r.text} amount of attempts ')
        else:
            print(r.text)
    stop = time.time()

print(f'total time was {stop - start} seconds')
# Out:
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# {401}
# ...

# %%
from flask import Flask, url_for, jsonify, request, Response
from string import ascii_uppercase

app = Flask(__name__)



@app.route('/', methods=['GET', 'POST'])
def api_root():
    SERVER_PASSWORD = 'PA'
    if request.method == 'POST':
        client_password = request.get_json()
        print(f'Server password is {SERVER_PASSWORD} client password is {client_password}')
        if(SERVER_PASSWORD == client_password['password']):
            return Response('{200}', 200)
        else: return Response('{401}', 401)
    else:
        d = 'my_json_123'
    return jsonify(d)


@app.route('/article/<string:article>')
def article_id(article):
    print(article)
    article = request.args.get('article')
    return f'Article is {article}'


if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
